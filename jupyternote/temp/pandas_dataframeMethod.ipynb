# %%
import pandas as pd
import re
import numpy as np

# %%
ex = pd.read_excel(r'D:\python\pynote\pandas\doc\d.xlsx',index_col=0)

# %%
ex
# Out:
#             日期1         日期2     日期    年份    月份    系统A    系统B   系统C  系统D  系统E  \
# 支队
# 一支队   2022.10.1  2022年10月1日  44835  2021  10.1  232.0  534.0  14.0   15   16
# 二支队   2022.10.2  2022年10月2日  44836  2022  10.3   42.0    NaN  15.0   16   17
# 三支队   2022.10.3  2022年10月3日  44837  2021  10.1   43.0   72.0  16.0   17   18
# 三支队   2022.10.3  2022年10月1日  44835  2023  10.3   23.0   72.0  19.0   18   19
# 四支队   2022.10.4  2022年10月4日  44838  2022  10.5  102.0  102.0   NaN   19   20
# 五支队   2022.10.5  2022年10月1日  44839  2021  10.5    NaN    NaN  68.0   20   21
# 五支队   2022.10.5  2022年10月4日  44835  2023  10.5    NaN    NaN  69.0   21   22
# 六支队   2022.10.6  2022年10月3日  44835  2021  10.1   65.0  162.0  70.0   22   23
# 一支队  2022.10.10  2022年10月1日  44835  2022  10.1   98.0  282.0  71.0   23   24
# 一支队  2022.10.13  2022年10月3日  44835  2023  10.3   65.0  372.0  72.0   24   25
# 一支队  2022.10.14  2022年10月1日  44835  2021  10.1  402.0  402.0  73.0   25   26
#
#      系统F  系统G  系统H  系统I
# 支队
# ...

# %%
arrays = [['Falcon', 'Falcon', 'Parrot', 'Parrot'],
          ['Captive', 'Wild', 'Captive', 'Wild']]

# %%
index = pd.MultiIndex.from_arrays(arrays, names=('Animal', 'Type'))

# %%
df = pd.DataFrame({'Max Speed': [390., 350., 30., 20.]},
                  index=index)

# %%
df
# Out:
#                 Max Speed
# Animal Type
# Falcon Captive      390.0
#        Wild         350.0
# Parrot Captive       30.0
#        Wild          20.0

# %%
df.groupby(level=0).mean()
# Out:
#         Max Speed
# Animal
# Falcon      370.0
# Parrot       25.0

# %%
df2 = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'Max Speed': [380., 370., 24., 26.]})

# %%
df2
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
df2.groupby("Animal", group_keys=True).apply(lambda x: x)
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
df2.groupby("Animal", group_keys=False).apply(lambda x: x)
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
df2.groupby('Animal',as_index=False).sum()
# Out:
#    Animal  Max Speed
# 0  Falcon      750.0
# 1  Parrot       50.0

# %%
df2.groupby('Animal',group_keys=False).sum()
# Out:
#         Max Speed
# Animal
# Falcon      750.0
# Parrot       50.0

# %%
ex
# Out:
#             日期1         日期2     日期    年份    月份    系统A    系统B   系统C  系统D  系统E  \
# 支队
# 一支队   2022.10.1  2022年10月1日  44835  2021  10.1  232.0  534.0  14.0   15   16
# 二支队   2022.10.2  2022年10月2日  44836  2022  10.3   42.0    NaN  15.0   16   17
# 三支队   2022.10.3  2022年10月3日  44837  2021  10.1   43.0   72.0  16.0   17   18
# 三支队   2022.10.3  2022年10月1日  44835  2023  10.3   23.0   72.0  19.0   18   19
# 四支队   2022.10.4  2022年10月4日  44838  2022  10.5  102.0  102.0   NaN   19   20
# 五支队   2022.10.5  2022年10月1日  44839  2021  10.5    NaN    NaN  68.0   20   21
# 五支队   2022.10.5  2022年10月4日  44835  2023  10.5    NaN    NaN  69.0   21   22
# 六支队   2022.10.6  2022年10月3日  44835  2021  10.1   65.0  162.0  70.0   22   23
# 一支队  2022.10.10  2022年10月1日  44835  2022  10.1   98.0  282.0  71.0   23   24
# 一支队  2022.10.13  2022年10月3日  44835  2023  10.3   65.0  372.0  72.0   24   25
# 一支队  2022.10.14  2022年10月1日  44835  2021  10.1  402.0  402.0  73.0   25   26
#
#      系统F  系统G  系统H  系统I
# 支队
# ...

# %%
ex.groupby(ex['日期2'].str[-2:]).sum()
# Out:
#          日期     年份    月份    系统A     系统B    系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 日期2
# 1日   224179  10108  51.1  755.0  1290.0  245.0  101  106  207  116  907  126
# 2日    44836   2022  10.3   42.0     0.0   15.0   16   17   42   19   42   21
# 3日   134507   6065  30.5  173.0   606.0  158.0   63   66  141   72  606   78
# 4日    89673   4045  21.0  102.0   102.0   69.0   40   42   92   46  234   50

# %%
def x(a):
    print(type(a),a)
    return a%2

# %%
ex.groupby(x).sum()
# Out:
# <class 'str'> 一支队
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-32f490d46cb2> in <module>
# ----> 1 ex.groupby(x).sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ...

# %%
df = pd.DataFrame({'B': [0, 1, 2, 3, 4]})

# %%
ex

# %%
data = ex.loc[:,'系统A':]

# %%
ex.groupby('支队').sum()
# Out:
#          日期    年份    月份    系统A     系统B    系统C  系统D  系统E  系统F  系统G   系统H  系统I
# 支队
# 一支队  179340  8087  40.6  797.0  1590.0  230.0   87   91  167   99  1075  107
# 三支队   89672  4044  20.4   66.0   144.0   35.0   35   37   87   41   144   45
# 二支队   44836  2022  10.3   42.0     0.0   15.0   16   17   42   19    42   21
# 五支队   89674  4044  21.0    0.0     0.0  137.0   41   43   93   47   264   51
# 六支队   44835  2021  10.1   65.0   162.0   70.0   22   23   48   25   162   27
# 四支队   44838  2022  10.5  102.0   102.0    0.0   19   20   45   22   102   24

# %%
ex.groupby('支队')['系统D'].mean().rename('dept').reset_index()
# Out:
#     支队   dept
# 0  一支队  21.75
# 1  三支队  17.50
# 2  二支队  16.00
# 3  五支队  20.50
# 4  六支队  22.00
# 5  四支队  19.00

# %%
d1 = ex.loc[:,['系统C','系统F']]

# %%
d1
# Out:
#       系统C  系统F
# 支队
# 一支队  14.0   17
# 二支队  15.0   42
# 三支队  16.0   43
# 三支队  19.0   44
# 四支队   NaN   45
# 五支队  68.0   46
# 五支队  69.0   47
# 六支队  70.0   48
# 一支队  71.0   49
# 一支队  72.0   50
# 一支队  73.0   51

# %%
d1.rename(columns={'系统C':'aaa','系统F':'bbb'})
# Out:
#       aaa  bbb
# 支队
# 一支队  14.0   17
# 二支队  15.0   42
# 三支队  16.0   43
# 三支队  19.0   44
# 四支队   NaN   45
# 五支队  68.0   46
# 五支队  69.0   47
# 六支队  70.0   48
# 一支队  71.0   49
# 一支队  72.0   50
# 一支队  73.0   51

# %%
d1.reset_index()
# Out:
#      支队   系统C  系统F
# 0   一支队  14.0   17
# 1   二支队  15.0   42
# 2   三支队  16.0   43
# 3   三支队  19.0   44
# 4   四支队   NaN   45
# 5   五支队  68.0   46
# 6   五支队  69.0   47
# 7   六支队  70.0   48
# 8   一支队  71.0   49
# 9   一支队  72.0   50
# 10  一支队  73.0   51

# %%
d1
# Out:
#       系统C  系统F
# 支队
# 一支队  14.0   17
# 二支队  15.0   42
# 三支队  16.0   43
# 三支队  19.0   44
# 四支队   NaN   45
# 五支队  68.0   46
# 五支队  69.0   47
# 六支队  70.0   48
# 一支队  71.0   49
# 一支队  72.0   50
# 一支队  73.0   51

# %%
d1.reset_index(inplace=True)

# %%
d1
# Out:
#      支队   系统C  系统F
# 0   一支队  14.0   17
# 1   二支队  15.0   42
# 2   三支队  16.0   43
# 3   三支队  19.0   44
# 4   四支队   NaN   45
# 5   五支队  68.0   46
# 6   五支队  69.0   47
# 7   六支队  70.0   48
# 8   一支队  71.0   49
# 9   一支队  72.0   50
# 10  一支队  73.0   51

# %%
d1.set_index('支队',inplace=True)

# %%
ex
# Out:
#             日期1         日期2     日期    年份    月份    系统A    系统B   系统C  系统D  系统E  \
# 支队
# 一支队   2022.10.1  2022年10月1日  44835  2021  10.1  232.0  534.0  14.0   15   16
# 二支队   2022.10.2  2022年10月2日  44836  2022  10.3   42.0    NaN  15.0   16   17
# 三支队   2022.10.3  2022年10月3日  44837  2021  10.1   43.0   72.0  16.0   17   18
# 三支队   2022.10.3  2022年10月1日  44835  2023  10.3   23.0   72.0  19.0   18   19
# 四支队   2022.10.4  2022年10月4日  44838  2022  10.5  102.0  102.0   NaN   19   20
# 五支队   2022.10.5  2022年10月1日  44839  2021  10.5    NaN    NaN  68.0   20   21
# 五支队   2022.10.5  2022年10月4日  44835  2023  10.5    NaN    NaN  69.0   21   22
# 六支队   2022.10.6  2022年10月3日  44835  2021  10.1   65.0  162.0  70.0   22   23
# 一支队  2022.10.10  2022年10月1日  44835  2022  10.1   98.0  282.0  71.0   23   24
# 一支队  2022.10.13  2022年10月3日  44835  2023  10.3   65.0  372.0  72.0   24   25
# 一支队  2022.10.14  2022年10月1日  44835  2021  10.1  402.0  402.0  73.0   25   26
#
#      系统F  系统G  系统H  系统I
# 支队
# ...

# %%
d1
# Out:
#       系统C  系统F
# 支队
# 一支队  14.0   17
# 二支队  15.0   42
# 三支队  16.0   43
# 三支队  19.0   44
# 四支队   NaN   45
# 五支队  68.0   46
# 五支队  69.0   47
# 六支队  70.0   48
# 一支队  71.0   49
# 一支队  72.0   50
# 一支队  73.0   51

# %%
c = ['cc','ff']

# %%
d1.rename(columns = str.lower)
# Out:
#       系统c  系统f
# 支队
# 一支队  14.0   17
# 二支队  15.0   42
# 三支队  16.0   43
# 三支队  19.0   44
# 四支队   NaN   45
# 五支队  68.0   46
# 五支队  69.0   47
# 六支队  70.0   48
# 一支队  71.0   49
# 一支队  72.0   50
# 一支队  73.0   51

# %%
d1.rename(str.lower ,axis = 1)
# Out:
#       系统c  系统f
# 支队
# 一支队  14.0   17
# 二支队  15.0   42
# 三支队  16.0   43
# 三支队  19.0   44
# 四支队   NaN   45
# 五支队  68.0   46
# 五支队  69.0   47
# 六支队  70.0   48
# 一支队  71.0   49
# 一支队  72.0   50
# 一支队  73.0   51

# %%
d1.rename({'系统C':'aaa','系统F':'bbb'},axis = 1)
# Out:
#       aaa  bbb
# 支队
# 一支队  14.0   17
# 二支队  15.0   42
# 三支队  16.0   43
# 三支队  19.0   44
# 四支队   NaN   45
# 五支队  68.0   46
# 五支队  69.0   47
# 六支队  70.0   48
# 一支队  71.0   49
# 一支队  72.0   50
# 一支队  73.0   51

# %%
d1
# Out:
#       系统C  系统F
# 支队
# 一支队  14.0   17
# 二支队  15.0   42
# 三支队  16.0   43
# 三支队  19.0   44
# 四支队   NaN   45
# 五支队  68.0   46
# 五支队  69.0   47
# 六支队  70.0   48
# 一支队  71.0   49
# 一支队  72.0   50
# 一支队  73.0   51

# %%
for i in zip(d1.columns,c):
    print(i)
# Out:
# ('系统C', 'cc')
# ('系统F', 'ff')

# %%
d1.rename(columns = {i:j for i,j in zip(d1.columns,c)})
# Out:
#        cc  ff
# 支队
# 一支队  14.0  17
# 二支队  15.0  42
# 三支队  16.0  43
# 三支队  19.0  44
# 四支队   NaN  45
# 五支队  68.0  46
# 五支队  69.0  47
# 六支队  70.0  48
# 一支队  71.0  49
# 一支队  72.0  50
# 一支队  73.0  51

# %%
d1.rename({'一支队':'aaa','二支队':'aaa'}, axis = 0('index'))
# Out:
#       系统C  系统F
# 支队
# 一支队  14.0   17
# 二支队  15.0   42
# 三支队  16.0   43
# 三支队  19.0   44
# 四支队   NaN   45
# 五支队  68.0   46
# 五支队  69.0   47
# 六支队  70.0   48
# 一支队  71.0   49
# 一支队  72.0   50
# 一支队  73.0   51

# %%
d1.rename(columns = str.lower)
# Out:
#       系统c  系统f
# 支队
# 一支队  14.0   17
# 二支队  15.0   42
# 三支队  16.0   43
# 三支队  19.0   44
# 四支队   NaN   45
# 五支队  68.0   46
# 五支队  69.0   47
# 六支队  70.0   48
# 一支队  71.0   49
# 一支队  72.0   50
# 一支队  73.0   51

# %%
d2 = d1.reset_index()

# %%
d2
# Out:
#      支队   系统C  系统F
# 0   一支队  14.0   17
# 1   二支队  15.0   42
# 2   三支队  16.0   43
# 3   三支队  19.0   44
# 4   四支队   NaN   45
# 5   五支队  68.0   46
# 6   五支队  69.0   47
# 7   六支队  70.0   48
# 8   一支队  71.0   49
# 9   一支队  72.0   50
# 10  一支队  73.0   51

# %%
d2.rename(index={0:'aa'},inplace=True)

# %%
d2.reset_index()
# Out:
#    index   支队   系统C  系统F
# 0     aa  一支队  14.0   17
# 1      1  二支队  15.0   42
# 2      2  三支队  16.0   43
# 3      3  三支队  19.0   44
# 4      4  四支队   NaN   45
# 5      5  五支队  68.0   46
# 6      6  五支队  69.0   47
# 7      7  六支队  70.0   48
# 8      8  一支队  71.0   49
# 9      9  一支队  72.0   50
# 10    10  一支队  73.0   51

# %%
d2.reset_index(col_fill='hello')
# Out:
#    index   支队   系统C  系统F
# 0     aa  一支队  14.0   17
# 1      1  二支队  15.0   42
# 2      2  三支队  16.0   43
# 3      3  三支队  19.0   44
# 4      4  四支队   NaN   45
# 5      5  五支队  68.0   46
# 6      6  五支队  69.0   47
# 7      7  六支队  70.0   48
# 8      8  一支队  71.0   49
# 9      9  一支队  72.0   50
# 10    10  一支队  73.0   51

# %%
d2.set_index('支队')
# Out:
#       系统C  系统F
# 支队
# 一支队  14.0   17
# 二支队  15.0   42
# 三支队  16.0   43
# 三支队  19.0   44
# 四支队   NaN   45
# 五支队  68.0   46
# 五支队  69.0   47
# 六支队  70.0   48
# 一支队  71.0   49
# 一支队  72.0   50
# 一支队  73.0   51

# %%
d3 = d2[0:4]

# %%
d3
# Out:
#      支队   系统C  系统F
# aa  一支队  14.0   17
# 1   二支队  15.0   42
# 2   三支队  16.0   43
# 3   三支队  19.0   44

# %%
d3.set_index(['a','b','c','d'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-426afa6da123> in <module>
# ----> 1 d3.set_index(['a','b','c','d'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['a', 'b', 'c', 'd'] are in the columns"

# %%
li = ['a','b','c','d']

# %%
li
# Out:
# ['a', 'b', 'c', 'd']

# %%
d3.set_index(li)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-d88afa5a8794> in <module>
# ----> 1 d3.set_index(li)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['a', 'b', 'c', 'd'] are in the columns"

# %%
pd.Series(li)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
d3.set_index(pd.Series(['a', 'b', 'c', 'd']))
# Out:
#     支队   系统C  系统F
# a  一支队  14.0   17
# b  二支队  15.0   42
# c  三支队  16.0   43
# d  三支队  19.0   44

# %%
d3.reset_index()
# Out:
#   index   支队   系统C  系统F
# 0    aa  一支队  14.0   17
# 1     1  二支队  15.0   42
# 2     2  三支队  16.0   43
# 3     3  三支队  19.0   44

# %%
d4 =d3.set_index('支队' ,append = True)

# %%
d4
# Out:
#          系统C  系统F
#    支队
# aa 一支队  14.0   17
# 1  二支队  15.0   42
# 2  三支队  16.0   43
# 3  三支队  19.0   44

# %%
d4.index
# Out:
# MultiIndex([('aa', '一支队'),
#             (   1, '二支队'),
#             (   2, '三支队'),
#             (   3, '三支队')],
#            names=[None, '支队'])

# %%
d3
# Out:
#      支队   系统C  系统F
# aa  一支队  14.0   17
# 1   二支队  15.0   42
# 2   三支队  16.0   43
# 3   三支队  19.0   44

# %%
d3.set_axis(['a','b','c','d'],axis = 'index')
# Out:
#     支队   系统C  系统F
# a  一支队  14.0   17
# b  二支队  15.0   42
# c  三支队  16.0   43
# d  三支队  19.0   44

# %%
d3.set_axis([2,3,4],axis='columns')
# Out:
#       2     3   4
# aa  一支队  14.0  17
# 1   二支队  15.0  42
# 2   三支队  16.0  43
# 3   三支队  19.0  44

# %%
d4
# Out:
#          系统C  系统F
#    支队
# aa 一支队  14.0   17
# 1  二支队  15.0   42
# 2  三支队  16.0   43
# 3  三支队  19.0   44

# %%
d4.set_axis(['a','b','c','d'],axis = 'index')
# Out:
#     系统C  系统F
# a  14.0   17
# b  15.0   42
# c  16.0   43
# d  19.0   44

# %%
d3
# Out:
#      支队   系统C  系统F
# aa  一支队  14.0   17
# 1   二支队  15.0   42
# 2   三支队  16.0   43
# 3   三支队  19.0   44

# %%
d3.rename_axis('number',axis='columns')
# Out:
# number   支队   系统C  系统F
# aa      一支队  14.0   17
# 1       二支队  15.0   42
# 2       三支队  16.0   43
# 3       三支队  19.0   44

# %%
d4
# Out:
#          系统C  系统F
#    支队
# aa 一支队  14.0   17
# 1  二支队  15.0   42
# 2  三支队  16.0   43
# 3  三支队  19.0   44

# %%
d4.rename_axis(['ccc','ddd'],axis='index')
# Out:
#           系统C  系统F
# ccc ddd
# aa  一支队  14.0   17
# 1   二支队  15.0   42
# 2   三支队  16.0   43
# 3   三支队  19.0   44

# %%
d5 = d4.rename_axis(['ccc','ddd'])

# %%
d5.index
# Out:
# MultiIndex([('aa', '一支队'),
#             (   1, '二支队'),
#             (   2, '三支队'),
#             (   3, '三支队')],
#            names=['ccc', 'ddd'])

# %%
d5
# Out:
#           系统C  系统F
# ccc ddd
# aa  一支队  14.0   17
# 1   二支队  15.0   42
# 2   三支队  16.0   43
# 3   三支队  19.0   44

# %%
d5.columns
# Out:
# Index(['系统C', '系统F'], dtype='object')

# %%
d5.loc[1]
# Out:
#       系统C  系统F
# ddd
# 二支队  15.0   42

# %%
d6 = d5.rename_axis('a',axis='columns')

# %%
d6
# Out:
# a         系统C  系统F
# ccc ddd
# aa  一支队  14.0   17
# 1   二支队  15.0   42
# 2   三支队  16.0   43
# 3   三支队  19.0   44

# %%
d6.index
# Out:
# MultiIndex([('aa', '一支队'),
#             (   1, '二支队'),
#             (   2, '三支队'),
#             (   3, '三支队')],
#            names=['ccc', 'ddd'])

# %%
d6.columns
# Out:
# Index(['系统C', '系统F'], dtype='object', name='a')

# %%
d6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 4 entries, ('aa', '一支队') to (3, '三支队')
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   系统C     4 non-null      float64
#  1   系统F     4 non-null      int64
# dtypes: float64(1), int64(1)
# memory usage: 512.0+ bytes

# %%
d3
# Out:
#      支队   系统C  系统F
# aa  一支队  14.0   17
# 1   二支队  15.0   42
# 2   三支队  16.0   43
# 3   三支队  19.0   44

# %%
d3.reindex(['a','b','c','d'],fill_value=0)
# Out:
#   支队  系统C  系统F
# a  0  0.0    0
# b  0  0.0    0
# c  0  0.0    0
# d  0  0.0    0

# %%
d3.add_prefix('xx')
# Out:
#    xx支队  xx系统C  xx系统F
# aa  一支队   14.0     17
# 1   二支队   15.0     42
# 2   三支队   16.0     43
# 3   三支队   19.0     44

# %%
d3
# Out:
#      支队   系统C  系统F
# aa  一支队  14.0   17
# 1   二支队  15.0   42
# 2   三支队  16.0   43
# 3   三支队  19.0   44

# %%
d4
# Out:
#          系统C  系统F
#    支队
# aa 一支队  14.0   17
# 1  二支队  15.0   42
# 2  三支队  16.0   43
# 3  三支队  19.0   44

# %%
d5
# Out:
#           系统C  系统F
# ccc ddd
# aa  一支队  14.0   17
# 1   二支队  15.0   42
# 2   三支队  16.0   43
# 3   三支队  19.0   44

# %%
d5.drop('系统C',axis='columns')
# Out:
#          系统F
# ccc ddd
# aa  一支队   17
# 1   二支队   42
# 2   三支队   43
# 3   三支队   44

# %%
d5.drop(1,axis=0)
# Out:
# C:\Users\flying\anaconda3\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#           系统C  系统F
# ccc ddd
# aa  一支队  14.0   17
# 2   三支队  16.0   43
# 3   三支队  19.0   44

# %%
d5
# Out:
#           系统C  系统F
# ccc ddd
# aa  一支队  14.0   17
# 1   二支队  15.0   42
# 2   三支队  16.0   43
# 3   三支队  19.0   44

# %%
d5.drop(1,level=0)
# Out:
#           系统C  系统F
# ccc ddd
# aa  一支队  14.0   17
# 2   三支队  16.0   43
# 3   三支队  19.0   44

# %%
d5.drop(['aa',2],level=0)
# Out:
#           系统C  系统F
# ccc ddd
# 1   二支队  15.0   42
# 3   三支队  19.0   44

# %%
data
# Out:
#        系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 一支队  232.0  534.0  14.0   15   16   17   18   19   20
# 二支队   42.0    NaN  15.0   16   17   42   19   42   21
# 三支队   43.0   72.0  16.0   17   18   43   20   72   22
# 三支队   23.0   72.0  19.0   18   19   44   21   72   23
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24
# 五支队    NaN    NaN  68.0   20   21   46   23  132   25
# 五支队    NaN    NaN  69.0   21   22   47   24  132   26
# 六支队   65.0  162.0  70.0   22   23   48   25  162   27
# 一支队   98.0  282.0  71.0   23   24   49   26  282   28
# 一支队   65.0  372.0  72.0   24   25   50   27  372   29
# 一支队  402.0  402.0  73.0   25   26   51   28  402   30

# %%
data.drop(index=['五支队','三支队'])
# Out:
#        系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 一支队  232.0  534.0  14.0   15   16   17   18   19   20
# 二支队   42.0    NaN  15.0   16   17   42   19   42   21
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24
# 六支队   65.0  162.0  70.0   22   23   48   25  162   27
# 一支队   98.0  282.0  71.0   23   24   49   26  282   28
# 一支队   65.0  372.0  72.0   24   25   50   27  372   29
# 一支队  402.0  402.0  73.0   25   26   51   28  402   30

# %%
data.drop(columns=['系统F','系统D'])
# Out:
#        系统A    系统B   系统C  系统E  系统G  系统H  系统I
# 支队
# 一支队  232.0  534.0  14.0   16   18   19   20
# 二支队   42.0    NaN  15.0   17   19   42   21
# 三支队   43.0   72.0  16.0   18   20   72   22
# 三支队   23.0   72.0  19.0   19   21   72   23
# 四支队  102.0  102.0   NaN   20   22  102   24
# 五支队    NaN    NaN  68.0   21   23  132   25
# 五支队    NaN    NaN  69.0   22   24  132   26
# 六支队   65.0  162.0  70.0   23   25  162   27
# 一支队   98.0  282.0  71.0   24   26  282   28
# 一支队   65.0  372.0  72.0   25   27  372   29
# 一支队  402.0  402.0  73.0   26   28  402   30

# %%
data.drop(['系统F','系统D'],axis=1)
# Out:
#        系统A    系统B   系统C  系统E  系统G  系统H  系统I
# 支队
# 一支队  232.0  534.0  14.0   16   18   19   20
# 二支队   42.0    NaN  15.0   17   19   42   21
# 三支队   43.0   72.0  16.0   18   20   72   22
# 三支队   23.0   72.0  19.0   19   21   72   23
# 四支队  102.0  102.0   NaN   20   22  102   24
# 五支队    NaN    NaN  68.0   21   23  132   25
# 五支队    NaN    NaN  69.0   22   24  132   26
# 六支队   65.0  162.0  70.0   23   25  162   27
# 一支队   98.0  282.0  71.0   24   26  282   28
# 一支队   65.0  372.0  72.0   25   27  372   29
# 一支队  402.0  402.0  73.0   26   28  402   30

# %%
data
# Out:
#        系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 一支队  232.0  534.0  14.0   15   16   17   18   19   20
# 二支队   42.0    NaN  15.0   16   17   42   19   42   21
# 三支队   43.0   72.0  16.0   17   18   43   20   72   22
# 三支队   23.0   72.0  19.0   18   19   44   21   72   23
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24
# 五支队    NaN    NaN  68.0   20   21   46   23  132   25
# 五支队    NaN    NaN  69.0   21   22   47   24  132   26
# 六支队   65.0  162.0  70.0   22   23   48   25  162   27
# 一支队   98.0  282.0  71.0   23   24   49   26  282   28
# 一支队   65.0  372.0  72.0   24   25   50   27  372   29
# 一支队  402.0  402.0  73.0   25   26   51   28  402   30

# %%
data
# Out:
#        系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 一支队  232.0  534.0  14.0   15   16   17   18   19   20
# 二支队   42.0    NaN  15.0   16   17   42   19   42   21
# 三支队   43.0   72.0  16.0   17   18   43   20   72   22
# 三支队   23.0   72.0  19.0   18   19   44   21   72   23
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24
# 五支队    NaN    NaN  68.0   20   21   46   23  132   25
# 五支队    NaN    NaN  69.0   21   22   47   24  132   26
# 六支队   65.0  162.0  70.0   22   23   48   25  162   27
# 一支队   98.0  282.0  71.0   23   24   49   26  282   28
# 一支队   65.0  372.0  72.0   24   25   50   27  372   29
# 一支队  402.0  402.0  73.0   25   26   51   28  402   30

# %%
data.drop_duplicates(subset = ['系统B'])
# Out:
#        系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 一支队  232.0  534.0  14.0   15   16   17   18   19   20
# 二支队   42.0    NaN  15.0   16   17   42   19   42   21
# 三支队   43.0   72.0  16.0   17   18   43   20   72   22
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24
# 六支队   65.0  162.0  70.0   22   23   48   25  162   27
# 一支队   98.0  282.0  71.0   23   24   49   26  282   28
# 一支队   65.0  372.0  72.0   24   25   50   27  372   29
# 一支队  402.0  402.0  73.0   25   26   51   28  402   30

# %%
data.drop_duplicates(subset = ['系统B'],keep='last')
# Out:
#        系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 一支队  232.0  534.0  14.0   15   16   17   18   19   20
# 三支队   23.0   72.0  19.0   18   19   44   21   72   23
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24
# 五支队    NaN    NaN  69.0   21   22   47   24  132   26
# 六支队   65.0  162.0  70.0   22   23   48   25  162   27
# 一支队   98.0  282.0  71.0   23   24   49   26  282   28
# 一支队   65.0  372.0  72.0   24   25   50   27  372   29
# 一支队  402.0  402.0  73.0   25   26   51   28  402   30

# %%
d1
# Out:
#       系统C  系统F
# 支队
# 一支队  14.0   17
# 二支队  15.0   42
# 三支队  16.0   43
# 三支队  19.0   44
# 四支队   NaN   45
# 五支队  68.0   46
# 五支队  69.0   47
# 六支队  70.0   48
# 一支队  71.0   49
# 一支队  72.0   50
# 一支队  73.0   51

# %%
data
# Out:
#        系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 一支队  232.0  534.0  14.0   15   16   17   18   19   20
# 二支队   42.0    NaN  15.0   16   17   42   19   42   21
# 三支队   43.0   72.0  16.0   17   18   43   20   72   22
# 三支队   23.0   72.0  19.0   18   19   44   21   72   23
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24
# 五支队    NaN    NaN  68.0   20   21   46   23  132   25
# 五支队    NaN    NaN  69.0   21   22   47   24  132   26
# 六支队   65.0  162.0  70.0   22   23   48   25  162   27
# 一支队   98.0  282.0  71.0   23   24   49   26  282   28
# 一支队   65.0  372.0  72.0   24   25   50   27  372   29
# 一支队  402.0  402.0  73.0   25   26   51   28  402   30

# %%
data.equals(d1)
# Out:
# False

# %%
d1.equals(data)
# Out:
# False

# %%
data.filter(items=['系统A','系统D'])
# Out:
#        系统A  系统D
# 支队
# 一支队  232.0   15
# 二支队   42.0   16
# 三支队   43.0   17
# 三支队   23.0   18
# 四支队  102.0   19
# 五支队    NaN   20
# 五支队    NaN   21
# 六支队   65.0   22
# 一支队   98.0   23
# 一支队   65.0   24
# 一支队  402.0   25

# %%
d6=data[0:2]

# %%
d8 = data.sample(3,random_state=2).iloc[:,[2,3,4]]

# %%
d7
# Out:
#        系统A    系统B
# 支队
# 四支队  102.0  102.0
# 二支队   42.0    NaN
# 一支队   65.0  372.0

# %%
d8
# Out:
#       系统C  系统D  系统E
# 支队
# 四支队   NaN   19   20
# 二支队  15.0   16   17
# 一支队  72.0   24   25

# %%
d7.merge(d8,left_on='支队',right_on='支队')
# Out:
#        系统A    系统B   系统C  系统D  系统E
# 支队
# 四支队  102.0  102.0   NaN   19   20
# 二支队   42.0    NaN  15.0   16   17
# 一支队   65.0  372.0  72.0   24   25

# %%
d7
# Out:
#        系统A    系统B
# 支队
# 四支队  102.0  102.0
# 二支队   42.0    NaN
# 一支队   65.0  372.0

# %%
d9 =d8.rename(columns={'系统C':'系统A','系统D':'系统B'})

# %%
d9
# Out:
#       系统A  系统B  系统E
# 支队
# 四支队   NaN   19   20
# 二支队  15.0   16   17
# 一支队  72.0   24   25

# %%
d7
# Out:
#        系统A    系统B
# 支队
# 四支队  102.0  102.0
# 二支队   42.0    NaN
# 一支队   65.0  372.0

# %%
d7.merge(d9,left_on='支队',right_on='支队',suffixes=['_left','_right'],how='left',sort=True,indicator=True)
# Out:
#      系统A_left  系统B_left  系统A_right  系统B_right  系统E _merge
# 支队
# 一支队      65.0     372.0       72.0         24   25   both
# 二支队      42.0       NaN       15.0         16   17   both
# 四支队     102.0     102.0        NaN         19   20   both

# %%
d71 = d7.reset_index()

# %%
d81 = d8.reset_index()

# %%
d6 = data.sample(5,random_state=5)

# %%
d61 = d6.reset_index()

# %%
d61
# Out:
#     支队    系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 0  五支队    NaN    NaN  68.0   20   21   46   23  132   25
# 1  一支队   98.0  282.0  71.0   23   24   49   26  282   28
# 2  三支队   43.0   72.0  16.0   17   18   43   20   72   22
# 3  一支队  402.0  402.0  73.0   25   26   51   28  402   30
# 4  四支队  102.0  102.0   NaN   19   20   45   22  102   24

# %%
d81
# Out:
#     支队   系统C  系统D  系统E
# 0  四支队   NaN   19   20
# 1  二支队  15.0   16   17
# 2  一支队  72.0   24   25

# %%
d61.merge(d81,on='支队')
# Out:
#     支队    系统A    系统B  系统C_x  系统D_x  系统E_x  系统F  系统G  系统H  系统I  系统C_y  系统D_y  \
# 0  一支队   98.0  282.0   71.0     23     24   49   26  282   28   72.0     24
# 1  一支队  402.0  402.0   73.0     25     26   51   28  402   30   72.0     24
# 2  四支队  102.0  102.0    NaN     19     20   45   22  102   24    NaN     19
#
#    系统E_y
# 0     25
# 1     25
# 2     20

# %%
d61.merge(d81,on='支队',how = 'outer')
# Out:
#     支队    系统A    系统B  系统C_x  系统D_x  系统E_x   系统F   系统G    系统H   系统I  系统C_y  \
# 0  五支队    NaN    NaN   68.0   20.0   21.0  46.0  23.0  132.0  25.0    NaN
# 1  一支队   98.0  282.0   71.0   23.0   24.0  49.0  26.0  282.0  28.0   72.0
# 2  一支队  402.0  402.0   73.0   25.0   26.0  51.0  28.0  402.0  30.0   72.0
# 3  三支队   43.0   72.0   16.0   17.0   18.0  43.0  20.0   72.0  22.0    NaN
# 4  四支队  102.0  102.0    NaN   19.0   20.0  45.0  22.0  102.0  24.0    NaN
# 5  二支队    NaN    NaN    NaN    NaN    NaN   NaN   NaN    NaN   NaN   15.0
#
#    系统D_y  系统E_y
# 0    NaN    NaN
# 1   24.0   25.0
# 2   24.0   25.0
# 3    NaN    NaN
# 4   19.0   20.0
# 5   16.0   17.0

# %%
d61.merge(d81,on='支队',how = 'outer',sort=True,indicator=True)
# Out:
#     支队    系统A    系统B  系统C_x  系统D_x  系统E_x   系统F   系统G    系统H   系统I  系统C_y  \
# 0  一支队   98.0  282.0   71.0   23.0   24.0  49.0  26.0  282.0  28.0   72.0
# 1  一支队  402.0  402.0   73.0   25.0   26.0  51.0  28.0  402.0  30.0   72.0
# 2  三支队   43.0   72.0   16.0   17.0   18.0  43.0  20.0   72.0  22.0    NaN
# 3  二支队    NaN    NaN    NaN    NaN    NaN   NaN   NaN    NaN   NaN   15.0
# 4  五支队    NaN    NaN   68.0   20.0   21.0  46.0  23.0  132.0  25.0    NaN
# 5  四支队  102.0  102.0    NaN   19.0   20.0  45.0  22.0  102.0  24.0    NaN
#
#    系统D_y  系统E_y      _merge
# 0   24.0   25.0        both
# 1   24.0   25.0        both
# 2    NaN    NaN   left_only
# 3   16.0   17.0  right_only
# 4    NaN    NaN   left_only
# 5   19.0   20.0        both

# %%
d61.merge(d81,on='支队',how='outer',indicator=True)
# Out:
#     支队    系统A    系统B  系统C_x  系统D_x  系统E_x   系统F   系统G    系统H   系统I  系统C_y  \
# 0  五支队    NaN    NaN   68.0   20.0   21.0  46.0  23.0  132.0  25.0    NaN
# 1  一支队   98.0  282.0   71.0   23.0   24.0  49.0  26.0  282.0  28.0   72.0
# 2  一支队  402.0  402.0   73.0   25.0   26.0  51.0  28.0  402.0  30.0   72.0
# 3  三支队   43.0   72.0   16.0   17.0   18.0  43.0  20.0   72.0  22.0    NaN
# 4  四支队  102.0  102.0    NaN   19.0   20.0  45.0  22.0  102.0  24.0    NaN
# 5  二支队    NaN    NaN    NaN    NaN    NaN   NaN   NaN    NaN   NaN   15.0
#
#    系统D_y  系统E_y      _merge
# 0    NaN    NaN   left_only
# 1   24.0   25.0        both
# 2   24.0   25.0        both
# 3    NaN    NaN   left_only
# 4   19.0   20.0        both
# 5   16.0   17.0  right_only

# %%
d6
# Out:
#        系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 五支队    NaN    NaN  68.0   20   21   46   23  132   25
# 一支队   98.0  282.0  71.0   23   24   49   26  282   28
# 三支队   43.0   72.0  16.0   17   18   43   20   72   22
# 一支队  402.0  402.0  73.0   25   26   51   28  402   30
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24

# %%
d7
# Out:
#        系统A    系统B
# 支队
# 四支队  102.0  102.0
# 二支队   42.0    NaN
# 一支队   65.0  372.0

# %%
d6.merge(d7,on='支队',how='left',indicator=True)
# Out:
#      系统A_x  系统B_x   系统C  系统D  系统E  系统F  系统G  系统H  系统I  系统A_y  系统B_y     _merge
# 支队
# 五支队    NaN    NaN  68.0   20   21   46   23  132   25    NaN    NaN  left_only
# 一支队   98.0  282.0  71.0   23   24   49   26  282   28   65.0  372.0       both
# 三支队   43.0   72.0  16.0   17   18   43   20   72   22    NaN    NaN  left_only
# 一支队  402.0  402.0  73.0   25   26   51   28  402   30   65.0  372.0       both
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24  102.0  102.0       both

# %%
data
# Out:
#        系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 一支队  232.0  534.0  14.0   15   16   17   18   19   20
# 二支队   42.0    NaN  15.0   16   17   42   19   42   21
# 三支队   43.0   72.0  16.0   17   18   43   20   72   22
# 三支队   23.0   72.0  19.0   18   19   44   21   72   23
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24
# 五支队    NaN    NaN  68.0   20   21   46   23  132   25
# 五支队    NaN    NaN  69.0   21   22   47   24  132   26
# 六支队   65.0  162.0  70.0   22   23   48   25  162   27
# 一支队   98.0  282.0  71.0   23   24   49   26  282   28
# 一支队   65.0  372.0  72.0   24   25   50   27  372   29
# 一支队  402.0  402.0  73.0   25   26   51   28  402   30

# %%
d6
# Out:
#        系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 五支队    NaN    NaN  68.0   20   21   46   23  132   25
# 一支队   98.0  282.0  71.0   23   24   49   26  282   28
# 三支队   43.0   72.0  16.0   17   18   43   20   72   22
# 一支队  402.0  402.0  73.0   25   26   51   28  402   30
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24

# %%
data.compare(d6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-352-393492be91b0> in <module>
# ----> 1 data.compare(d6)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in compare(self, other, align_axis, keep_shape, keep_equal)
#    6213         keep_equal: bool = False,
#    6214     ) -> DataFrame:
# -> 6215         return super().compare(
#    6216             other=other,
#    6217             align_axis=align_axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in compare(self, other, align_axis, keep_shape, keep_equal)
#    8656             )
#    8657
# -> 8658         mask = ~((self == other) | (self.isna() & other.isna()))
#    8659         keys = ["self", "other"]
#    8660
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ...

# %%
data.iloc[1,1]=999

# %%
d0 = data

# %%
d0
# Out:
#        系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 一支队  232.0  534.0  14.0   15   16   17   18   19   20
# 二支队   42.0  999.0  15.0   16   17   42   19   42   21
# 三支队   43.0   72.0  16.0   17   18   43   20   72   22
# 三支队   23.0   72.0  19.0   18   19   44   21   72   23
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24
# 五支队    NaN    NaN  68.0   20   21   46   23  132   25
# 五支队    NaN    NaN  69.0   21   22   47   24  132   26
# 六支队   65.0  162.0  70.0   22   23   48   25  162   27
# 一支队   98.0  282.0  71.0   23   24   49   26  282   28
# 一支队   65.0  372.0  72.0   24   25   50   27  372   29
# 一支队  402.0  402.0  73.0   25   26   51   28  402   30

# %%
data.iloc[1,1]=10000

# %%
d0 = data.copy()

# %%
d0
# Out:
#        系统A     系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 一支队  232.0   534.0  14.0   15   16   17   18   19   20
# 二支队   42.0  9999.0  15.0   16   17   42   19   42   21
# 三支队   43.0    72.0  16.0   17   18   43   20   72   22
# 三支队   23.0    72.0  19.0   18   19   44   21   72   23
# 四支队  102.0   102.0   NaN   19   20   45   22  102   24
# 五支队    NaN     NaN  68.0   20   21   46   23  132   25
# 五支队    NaN     NaN  69.0   21   22   47   24  132   26
# 六支队   65.0   162.0  70.0   22   23   48   25  162   27
# 一支队   98.0   282.0  71.0   23   24   49   26  282   28
# 一支队   65.0   372.0  72.0   24   25   50   27  372   29
# 一支队  402.0   402.0  73.0   25   26   51   28  402   30

# %%
d0.compare(data)
# Out:
#         系统B
#        self    other
# 支队
# 二支队  9999.0  10000.0

# %%
d7
# Out:
#        系统A    系统B
# 支队
# 四支队  102.0  102.0
# 二支队   42.0    NaN
# 一支队   65.0  372.0

# %%
d7.assign(cc=[12,3,2])
# Out:
#        系统A    系统B  cc
# 支队
# 四支队  102.0  102.0  12
# 二支队   42.0    NaN   3
# 一支队   65.0  372.0   2

# %%
d7.assign(dd=pd.Series([3,2,4]))
# Out:
#        系统A    系统B  dd
# 支队
# 四支队  102.0  102.0 NaN
# 二支队   42.0    NaN NaN
# 一支队   65.0  372.0 NaN

# %%
b =pd.Series([3,2,4])

# %%
b
# Out:
# 0    3
# 1    2
# 2    4
# dtype: int64

# %%
d7.assign(ee = b)
# Out:
#        系统A    系统B  ee
# 支队
# 四支队  102.0  102.0 NaN
# 二支队   42.0    NaN NaN
# 一支队   65.0  372.0 NaN

# %%
b.set_index(['四支队','二支队','一支队'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-380-08cf9615db1c> in <module>
# ----> 1 b.set_index(['四支队','二支队','一支队'])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'set_index'

# %%
c =b.set_axis(['四支队','二支队','一支队'])

# %%
d7.assign(ee=c)
# Out:
#        系统A    系统B  ee
# 支队
# 四支队  102.0  102.0   3
# 二支队   42.0    NaN   2
# 一支队   65.0  372.0   4

# %%
d7.set_axis(index=(0,1,2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-385-5e4860a46d91> in <module>
# ----> 1 d7.set_axis(index=(0,1,2))
#
# TypeError: set_axis() got an unexpected keyword argument 'index'

# %%
d77 = d7.set_axis([0,1,2])

# %%
d77.assign(cc = pd.Series([2,3,4]))
# Out:
#      系统A    系统B  cc
# 0  102.0  102.0   2
# 1   42.0    NaN   3
# 2   65.0  372.0   4

# %%
d7.sum(1)
# Out:
# 支队
# 四支队    204.0
# 二支队     42.0
# 一支队    437.0
# dtype: float64

# %%
ds= d7.sum(1)

# %%
d7
# Out:
#        系统A    系统B
# 支队
# 四支队  102.0  102.0
# 二支队   42.0    NaN
# 一支队   65.0  372.0

# %%
d7.assign(总和 = d7.sum(1))
# Out:
#        系统A    系统B     总和
# 支队
# 四支队  102.0  102.0  204.0
# 二支队   42.0    NaN   42.0
# 一支队   65.0  372.0  437.0

# %%
data
# Out:
#        系统A      系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 一支队  232.0    534.0  14.0   15   16   17   18   19   20
# 二支队   42.0  10000.0  15.0   16   17   42   19   42   21
# 三支队   43.0     72.0  16.0   17   18   43   20   72   22
# 三支队   23.0     72.0  19.0   18   19   44   21   72   23
# 四支队  102.0    102.0   NaN   19   20   45   22  102   24
# 五支队    NaN      NaN  68.0   20   21   46   23  132   25
# 五支队    NaN      NaN  69.0   21   22   47   24  132   26
# 六支队   65.0    162.0  70.0   22   23   48   25  162   27
# 一支队   98.0    282.0  71.0   23   24   49   26  282   28
# 一支队   65.0    372.0  72.0   24   25   50   27  372   29
# 一支队  402.0    402.0  73.0   25   26   51   28  402   30

# %%
data.drop(columns=['系统F','系统G'])
# Out:
#        系统A      系统B   系统C  系统D  系统E  系统H  系统I
# 支队
# 一支队  232.0    534.0  14.0   15   16   19   20
# 二支队   42.0  10000.0  15.0   16   17   42   21
# 三支队   43.0     72.0  16.0   17   18   72   22
# 三支队   23.0     72.0  19.0   18   19   72   23
# 四支队  102.0    102.0   NaN   19   20  102   24
# 五支队    NaN      NaN  68.0   20   21  132   25
# 五支队    NaN      NaN  69.0   21   22  132   26
# 六支队   65.0    162.0  70.0   22   23  162   27
# 一支队   98.0    282.0  71.0   23   24  282   28
# 一支队   65.0    372.0  72.0   24   25  372   29
# 一支队  402.0    402.0  73.0   25   26  402   30

# %%
d6
# Out:
#        系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 五支队    NaN    NaN  68.0   20   21   46   23  132   25
# 一支队   98.0  282.0  71.0   23   24   49   26  282   28
# 三支队   43.0   72.0  16.0   17   18   43   20   72   22
# 一支队  402.0  402.0  73.0   25   26   51   28  402   30
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24

# %%
d7
# Out:
#        系统A    系统B
# 支队
# 四支队  102.0  102.0
# 二支队   42.0    NaN
# 一支队   65.0  372.0

# %%
d6.merge(d7,on='系统B',indicator=True)
# Out:
#    系统A_x    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I  系统A_y _merge
# 0    NaN    NaN  68.0   20   21   46   23  132   25   42.0   both
# 1  102.0  102.0   NaN   19   20   45   22  102   24  102.0   both

# %%
d6.merge(d7,on='系统B',indicator=True,how='outer')
# Out:
#    系统A_x    系统B   系统C   系统D   系统E   系统F   系统G    系统H   系统I  系统A_y      _merge
# 0    NaN    NaN  68.0  20.0  21.0  46.0  23.0  132.0  25.0   42.0        both
# 1   98.0  282.0  71.0  23.0  24.0  49.0  26.0  282.0  28.0    NaN   left_only
# 2   43.0   72.0  16.0  17.0  18.0  43.0  20.0   72.0  22.0    NaN   left_only
# 3  402.0  402.0  73.0  25.0  26.0  51.0  28.0  402.0  30.0    NaN   left_only
# 4  102.0  102.0   NaN  19.0  20.0  45.0  22.0  102.0  24.0  102.0        both
# 5    NaN  372.0   NaN   NaN   NaN   NaN   NaN    NaN   NaN   65.0  right_only

# %%
d6.merge(d7,left_on='系统B',right_on='系统B',indicator=True,how='outer')
# Out:
#    系统A_x    系统B   系统C   系统D   系统E   系统F   系统G    系统H   系统I  系统A_y      _merge
# 0    NaN    NaN  68.0  20.0  21.0  46.0  23.0  132.0  25.0   42.0        both
# 1   98.0  282.0  71.0  23.0  24.0  49.0  26.0  282.0  28.0    NaN   left_only
# 2   43.0   72.0  16.0  17.0  18.0  43.0  20.0   72.0  22.0    NaN   left_only
# 3  402.0  402.0  73.0  25.0  26.0  51.0  28.0  402.0  30.0    NaN   left_only
# 4  102.0  102.0   NaN  19.0  20.0  45.0  22.0  102.0  24.0  102.0        both
# 5    NaN  372.0   NaN   NaN   NaN   NaN   NaN    NaN   NaN   65.0  right_only

# %%
pd.Series([1,2,3],name='num',index=['a','b','c'])
# Out:
# a    1
# b    2
# c    3
# Name: num, dtype: int64

# %%
d7
# Out:
#        系统A    系统B
# 支队
# 四支队  102.0  102.0
# 二支队   42.0    NaN
# 一支队   65.0  372.0

# %%
d7.loc['三支队']=[32,84]

# %%
d7
# Out:
#        系统A    系统B
# 支队
# 四支队  102.0    NaN
# 二支队   42.0    NaN
# 一支队   65.0  372.0
# 三支队   32.0   84.0

# %%
d7.loc['四支队','系统B'] = np.nan

# %%
d7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 四支队 to 三支队
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   系统A     4 non-null      float64
#  1   系统B     2 non-null      object
# dtypes: float64(1), object(1)
# memory usage: 268.0+ bytes

# %%
d7.loc['二支队','系统B'].__class__
# Out:
# float

# %%
d6
# Out:
#        系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 五支队    NaN    NaN  68.0   20   21   46   23  132   25
# 一支队   65.0  372.0  71.0   23   24   49   26  282   28
# 三支队   32.0   84.0  16.0   17   18   43   20   72   22
# 一支队   65.0  372.0  73.0   25   26   51   28  402   30
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24

# %%
d6.update(d7)

# %%
d6
# Out:
#        系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 五支队    NaN    NaN  68.0   20   21   46   23  132   25
# 一支队   65.0  372.0  71.0   23   24   49   26  282   28
# 三支队   32.0   84.0  16.0   17   18   43   20   72   22
# 一支队   65.0  372.0  73.0   25   26   51   28  402   30
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24

# %%
d7
# Out:
#        系统A   系统B
# 支队
# 四支队  102.0   NaN
# 二支队   42.0   NaN
# 一支队   65.0  1000
# 三支队   32.0  84.0

# %%
d7.iloc[2,1]=1000

# %%
d6
# Out:
#        系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 五支队    NaN    NaN  68.0   20   21   46   23  132   25
# 一支队   65.0  372.0  71.0   23   24   49   26  282   28
# 三支队   32.0   84.0  16.0   17   18   43   20   72   22
# 一支队   65.0  372.0  73.0   25   26   51   28  402   30
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24

# %%
d6.update(d7,overwrite=False)

# %%
d6
# Out:
#        系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 五支队    NaN    NaN  68.0   20   21   46   23  132   25
# 一支队   65.0   1000  71.0   23   24   49   26  282   28
# 三支队   32.0   84.0  16.0   17   18   43   20   72   22
# 一支队   65.0   1000  73.0   25   26   51   28  402   30
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24

# %%
d6.sum().rename_axis('cc')
# Out:
# cc
# 系统A     264.0
# 系统B    2186.0
# 系统C     228.0
# 系统D       104
# 系统E       109
# 系统F       234
# 系统G       119
# 系统H       990
# 系统I       129
# dtype: object

# %%
d6.append(d6.sum().rename_axis('cc'),ignore_index=True)
# Out:
#      系统A     系统B    系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 0    NaN     NaN   68.0   20   21   46   23  132   25
# 1   65.0    1000   71.0   23   24   49   26  282   28
# 2   32.0    84.0   16.0   17   18   43   20   72   22
# 3   65.0    1000   73.0   25   26   51   28  402   30
# 4  102.0   102.0    NaN   19   20   45   22  102   24
# 5  264.0  2186.0  228.0  104  109  234  119  990  129

# %%
d6
# Out:
#        系统A    系统B   系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 五支队    NaN    NaN  68.0   20   21   46   23  132   25
# 一支队   65.0   1000  71.0   23   24   49   26  282   28
# 三支队   32.0   84.0  16.0   17   18   43   20   72   22
# 一支队   65.0   1000  73.0   25   26   51   28  402   30
# 四支队  102.0  102.0   NaN   19   20   45   22  102   24

# %%
d6.loc['总和'] = d6.sum()

# %%
d6
# Out:
#        系统A     系统B    系统C  系统D  系统E  系统F  系统G  系统H  系统I
# 支队
# 五支队    NaN     NaN   68.0   20   21   46   23  132   25
# 一支队   65.0    1000   71.0   23   24   49   26  282   28
# 三支队   32.0    84.0   16.0   17   18   43   20   72   22
# 一支队   65.0    1000   73.0   25   26   51   28  402   30
# 四支队  102.0   102.0    NaN   19   20   45   22  102   24
# 总和   264.0  2186.0  228.0  104  109  234  119  990  129

# %%
d6.assign(总和=d6.sum(1))
# Out:
#        系统A     系统B    系统C  系统D  系统E  系统F  系统G  系统H  系统I      总和
# 支队
# 五支队    NaN     NaN   68.0   20   21   46   23  132   25   335.0
# 一支队   65.0    1000   71.0   23   24   49   26  282   28  1568.0
# 三支队   32.0    84.0   16.0   17   18   43   20   72   22   324.0
# 一支队   65.0    1000   73.0   25   26   51   28  402   30  1700.0
# 四支队  102.0   102.0    NaN   19   20   45   22  102   24   436.0
# 总和   264.0  2186.0  228.0  104  109  234  119  990  129  4363.0

# %%
d6.loc[:,'总和'] = d6.sum(1)

# %%
d6
# Out:
#        系统A     系统B    系统C  系统D  系统E  系统F  系统G  系统H  系统I      总和
# 支队
# 五支队    NaN     NaN   68.0   20   21   46   23  132   25   335.0
# 一支队   65.0    1000   71.0   23   24   49   26  282   28  1568.0
# 三支队   32.0    84.0   16.0   17   18   43   20   72   22   324.0
# 一支队   65.0    1000   73.0   25   26   51   28  402   30  1700.0
# 四支队  102.0   102.0    NaN   19   20   45   22  102   24   436.0
# 总和   264.0  2186.0  228.0  104  109  234  119  990  129  4363.0

# %%
d7
# Out:
#        系统A   系统B
# 支队
# 四支队  102.0   NaN
# 二支队   42.0   NaN
# 一支队   65.0  1000
# 三支队   32.0  84.0

# %%
d7.iloc[2]=[12,23]

# %%
d7
# Out:
#        系统A   系统B
# 支队
# 四支队  102.0   NaN
# 二支队   42.0   NaN
# 一支队   12.0    23
# 三支队   32.0  84.0

# %%
d7.iloc[:,1] = [np.nan,23,4,5]

# %%
d7
# Out:
#        系统A   系统B
# 支队
# 四支队  102.0   NaN
# 二支队   42.0  23.0
# 一支队   12.0   4.0
# 三支队   32.0   5.0

# %%
d7.sum().rename('total')
# Out:
# 系统A    188.0
# 系统B     32.0
# Name: total, dtype: float64

# %%
d7.append(d7.sum(),ignore_index=True)
# Out:
#      系统A   系统B
# 0  102.0   NaN
# 1   42.0  23.0
# 2   12.0   4.0
# 3   32.0   5.0
# 4  188.0  32.0

# %%
d7.append(d7.sum().rename('总和'))
# Out:
#        系统A   系统B
# 支队
# 四支队  102.0   NaN
# 二支队   42.0  23.0
# 一支队   12.0   4.0
# 三支队   32.0   5.0
# 总和   188.0  32.0

# %%
d7.append(d7.sum().rename('总和'))
# Out:
#        系统A   系统B
# 支队
# 四支队  102.0   NaN
# 二支队   42.0  23.0
# 一支队   12.0   4.0
# 三支队   32.0   5.0
# 总和   188.0  32.0

# %%
d7.sum('index')
# Out:
# 系统A    188.0
# 系统B     32.0
# dtype: float64

# %%
d7.sum(0)
# Out:
# 系统A    188.0
# 系统B     32.0
# dtype: float64

# %%
d7
# Out:
#        系统A   系统B
# 支队
# 四支队  102.0   NaN
# 二支队   42.0  23.0
# 一支队   12.0   4.0
# 三支队   32.0   5.0

# %%
d77
# Out:
#      系统A    系统B
# 0  102.0  102.0
# 1   42.0    NaN
# 2   65.0  372.0

# %%
d7
# Out:
#        系统A   系统B
# 支队
# 四支队  102.0   NaN
# 二支队   42.0  23.0
# 一支队   12.0   4.0
# 三支队   32.0   5.0

# %%
pd.concat([d7,d7],axis=0)
# Out:
#        系统A   系统B
# 支队
# 四支队  102.0   NaN
# 二支队   42.0  23.0
# 一支队   12.0   4.0
# 三支队   32.0   5.0
# 四支队  102.0   NaN
# 二支队   42.0  23.0
# 一支队   12.0   4.0
# 三支队   32.0   5.0

# %%
df1 = pd.DataFrame([['a', 1], ['b', 2]],
                   columns=['letter', 'number'])

# %%
df1
# Out:
#   letter  number
# 0      a       1
# 1      b       2

# %%
df2 = pd.DataFrame([['c', 3], ['d', 4]],
                   columns=['letter', 'number'])

# %%
df2
# Out:
#   letter  number
# 0      c       3
# 1      d       4

# %%
pd.concat([df1,df2])
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
pd.concat([df1,df2],ignore_index=True,sort=False)
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 2      c       3
# 3      d       4

# %%
df3 = pd.DataFrame([['c', 3, 'cat'], ['d', 4, 'dog']],
                   columns=['letter', 'number', 'animal'])

# %%
df3
# Out:
#   letter  number animal
# 0      c       3    cat
# 3      d       4    dog

# %%
df3.rename({1:3},axis=0,inplace=True)

# %%
df1
# Out:
#   letter  number
# 0      a       1
# 1      b       2

# %%
pd.concat([df1,df3],join='inner',axis=1)
# Out:
#   letter  number letter  number animal
# 0      a       1      c       3    cat

# %%
d1=pd.DataFrame([[1,2,3],[2,3,4]],columns=['a','b','c'],index=['h','j'])

# %%
d1
# Out:
#    a  b  c
# h  1  2  3
# j  2  3  4

# %%
d1.to_json(orient='split')
# Out:
# '{"columns":["a","b","c"],"index":["h","j"],"data":[[1,2,3],[2,3,4]]}'
